# %%
# !pip install langchain_community  youtube-transcript-api pytube deep-translator chromadb gradio langchain_groq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.3/622.3 kB 35.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 73.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.9/321.9 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 22.3 MB/s eta 0:00:00
# ...

# %%
youtube_urls={'simple_and_multiple_linear_regression':'https://youtu.be/aa24u6f744Y?si=wyoulLTY3QUhdMZz'
,'regression_anlaysis_prediction_marketing_data':'https://youtu.be/aa24u6f744Y?si=wyoulLTY3QUhdMZz',
              'variance_covariance_coorelation_in_detail':'https://youtu.be/NXPihJtSPdY?si=iXSekJBO4ntl7nOB',
              'statics':'https://youtu.be/91DJhczhh1s?si=dt76hFCy0kW9keCU',
              'data_preperation_task_card_data':"https://youtu.be/TOa5AizCqzQ?si=9_GQeDYpnfZ4RQNx",
              "groupby_and_data_aggregation":"https://youtu.be/tbk87Zywi3Y?si=lpB81aCdD0fsCS4F",
              "pandas_merging_data":'https://youtu.be/ONfdln2_JLk?si=FDmpDhT8LMMpoYgh',
              "data_wragling":'https://youtu.be/VYXY-eup8fY?si=ZY2QQO2Tlel581_q',
              "data_transformation":'https://youtu.be/cB2scxUffJs?si=mdUQ9eA62_6XAa5v',
              "data_quering_in_pandas":"https://youtu.be/dQrPyzmcz60?si=87Pw5DnzmE18PvUi",
              "data_cleaning":'https://youtu.be/wxIm_Rn8fw8?si=rJlZUe_d-jzYLchx',
              'series_and_dataframe':'https://youtu.be/Dmb7lrTh_Ps?si=NZwuhFzGAWsKluzh',
              'file_reading_and_writing':'https://youtu.be/3GQtt7ZgOPI?si=IcIx6f_PoJ2Zk9UI',
              'access_modeifier_public_and_private':"https://youtu.be/XsZ_QAADMDk?si=chrr3P-FNE5O1QZ7",
              "multiple_and_multi_level_inheritence":"https://youtu.be/Rl9KOEnA1U8?si=KU_o9VpB6YOwdD9v",
              "funtion_class_object":"https://youtu.be/kNQ-sKY4rL0?si=4yJHW_SSs6M16jYj",
              "oop":"https://youtu.be/7RR3HQJZNrQ?si=RMLYWlYp0YlWajeN",
              "oop_inheritence_polymorhism":"https://youtu.be/WQ4XtNmW_84?si=gzpAhL_MXA9foCrj",
              "data_science_distributions":"https://youtu.be/cYx_2Smgbow?si=bM1syjF_sS751vAH",
              "python_functions_1":"https://youtu.be/gXlaeovGhw8?si=inzBwFqK2N76fx-P",
              "python_functions_2":"https://youtu.be/vJW2xWimXOE?si=GqBa3a9jBg9k1_Qn",
              "python_for_loops_working_list":"https://youtu.be/Vmjb-JQ6d2A?si=wT6D90xacpGEnTEe",
              "python_while_loops":"https://youtu.be/AqVlkAv2Jmo?si=Si26A89VfGqN15eB",
              "python_logical_and_or_operators":"https://youtu.be/mRZuLJc1sZc?si=n7uV0pKO2p69T11a",
              "python_dictionary_collections":"https://youtu.be/w7ILQ4UVjhs?si=zT8Hi3Qsx4tmN9tc",
              "python_collections_list":"https://youtu.be/p5yPAfSPtw4?si=sPzw7hTprBowNvXo",
              "python_string_collections":"https://youtu.be/XScFYcs1_Oc?si=7tqyYOuLdzqkCmi5",
              "operator_and_if_else":"https://youtu.be/LF2ZtqKBFBQ?si=A4GYBfpFUeROYh3c",
              "class4(13May)":"https://youtu.be/TbmCDP2CWlQ?si=w1kObOL8QjpPqVZN",
              "anaconda_intallations":"https://youtu.be/PQuWRLjlA_A?si=xbkgwkX4CRemcjeV",
              "python_operators_and_expressions_solving":"https://youtu.be/ytgwavd1aiQ?si=P0pBNOk1zYSSmylU"}

# %%
import langchain
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage
from langchain.document_loaders import YoutubeLoader

# %%
loader=YoutubeLoader.from_youtube_url(youtube_urls['statics'],language='hi')

# %%
doc=loader.load()[0].page_content

# %%
from deep_translator import GoogleTranslator

translator = GoogleTranslator(source="hi", target="en")
hindi_text = "नमस्ते, आप कैसे हैं?"
translated_text = translator.translate(hindi_text)
print(translated_text)
# Out:
# hello how are you?

# %%
for i in range(0,len(doc),3000):
  text=doc[i:i+2000]
  translated_text = translator.translate(text)
  print(translated_text)
  break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-be7f03820c6f> in <cell line: 0>()
# ----> 1 for i in range(0,len(doc),3000):
#       2   text=doc[i:i+2000]
#       3   translated_text = translator.translate(text)
#       4   print(translated_text)
#       5   break
#
# NameError: name 'doc' is not defined

# %%
len(doc.split())
# Out:
# 7155

# %%
for i in range(0,7155,2000):
  print(i,i+2000)
# Out:
# 0 2000
# 2000 4000
# 4000 6000
# 6000 8000

# %%
len(str(doc))
# Out:
# 31243

# %%
#doc divide in to 2000 chunks
for i in range(0,len(doc),2000):
  print(doc[i:i+2000])
# Out:
# अच्छा जी मैंने एक डाटा सेट ले लिया एड बजट एंड सेल्ड सीएसवी दे नहीं ट में क्या है आप लोगों को डाटा सेट में शेयर कर देता हूं एयरफोर्स शेर प ठीक है तो लोड करके देखते हैं क्या निकलता है और हम इसके अंदर क्या कर सकते हैं [संगीत] ठीक है ये मैंने डाल दिया इसम एडवरटाइजिंग बजट एंड सेल्स सीस नई फाइल ले रहा हूं और कोई बता दो पसल नंबर लैपटॉप है नहीं हाथ प रख के बैठा हुआ है प भी डाल दूं यहां भी डाल दूं काम क्यों नहीं कर रहा अभी कहां गया लैपटॉप पहले तो लेके आ र पहले इस्तेमाल अब इस्तेमाल नहीं है क्या हो गया है क्या प चल रहा है क्या डेट है आज 21 20 ठीक है अच्छा अब देखो रिकॉर्डिंग चल रही है मेरा बच्चा देखो सबसे पहले तो हमने जार भाई डाटा लोड करना है है ना इंपोर्ट मैं यहां पर एयरफोर्स शेयर प एक चीज और रख रहा हूं ठीक है दैट इज लाइट कम कर दो यार आगे की भाई को नींद आ रही है ये एक पीडीएफ रखी है मैंने छोटी सी दिस इज अ जस्ट लाइक अ चीट शीट हमारा जल्दी से काम हो जाएगा इससे ठीक है तो इंपोर्ट पंडा एज पीडी पहला इंपोर्ट हमें अभी यही चाहिए डाटा के लिए मैं कह देता हूं पडी डॉट रीड एक्सल था सी स ठीक है क्या नाम था भाई 
# ...

# %%
def long_text_transalte(doc):
  doc=str(doc)
  translate_text=''.join([translator.translate(doc[i:i+2000]) for i in range(0,len(doc),2000)])
  return translate_text

# %%
tran=long_text_transalte(doc)

# %%
print(tran)
# Out:
# I would have got it revised, I had not read anything, I kept reading the same things that I had been reading since childhood, what all things brother, we had read mean, median, mode, and we had read variance and standard deviation, and what else had we read, now what is covariate, everyone knows this, right? Yes, what do you know about this, tell me from these, okay, you know variance, everyone knows variance, everyone knows variance, variance, ok, look brother, main median mode, so what do we have in simple terms, what is the central tendency of our data, okay, mean median mode tells the center of our data, what does median also do, it tells the center of our data, so then what is the difference between mean and median, if there is an outlier in our data, then what can we do through median, we can find the correct mean, the correct center, otherwise what happens due to outlier, the mind gets disturbed, what is mode, the most repeated value, when do we usually use it, when our data i
# ...

# %%
# !mkdir nasir

# %%
for file_name,url in youtube_urls.items():
  loader=YoutubeLoader.from_youtube_url(url,language='hi')
  doc=loader.load()[0].page_content
  tran=long_text_transalte(doc)
  with open(f'nasir/{file_name}.txt','w') as f:
    f.write(tran)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-b56eaeaec221> in <cell line: 0>()
#       1 for file_name,url in youtube_urls.items():
#       2   loader=YoutubeLoader.from_youtube_url(url,language='hi')
# ----> 3   doc=loader.load()[0].page_content
#       4   tran=long_text_transalte(doc)
#       5   with open(f'nasir/{file_name}.txt','w') as f:
#
# IndexError: list index out of range

# %%
#nasir folder i have zip
# !zip -r nasir.zip nasir
# Out:
#   adding: nasir/ (stored 0%)
#   adding: nasir/python_functions_1.txt (deflated 68%)
#   adding: nasir/class4(13May).txt (deflated 68%)
#   adding: nasir/python_functions_2.txt (deflated 69%)
#   adding: nasir/python_collections_list.txt (deflated 68%)
#   adding: nasir/file_reading_and_writing.txt (deflated 67%)
#   adding: nasir/pandas_merging_data.txt (deflated 68%)
#   adding: nasir/simple_and_multiple_linear_regression.txt (deflated 67%)
#   adding: nasir/operator_and_if_else.txt (deflated 68%)
#   adding: nasir/data_quering_in_pandas.txt (deflated 67%)
#   adding: nasir/oop.txt (deflated 46%)
#   adding: nasir/data_cleaning.txt (deflated 68%)
#   adding: nasir/python_for_loops_working_list.txt (deflated 67%)
#   adding: nasir/multiple_and_multi_level_inheritence.txt (deflated 69%)
#   adding: nasir/python_string_collections.txt (deflated 67%)
#   adding: nasir/regression_anlaysis_prediction_marketing_data.txt (deflated 67%)
# ...

# %%
from langchain.document_loaders import TextLoader,DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
from google.colab import userdata
from langchain_groq import ChatGroq
from langchain import HuggingFaceHub

# %%
loader=DirectoryLoader(
    path='nasir/',
    glob='**/*.txt',
    show_progress=True,
    loader_cls=TextLoader
)

# %%
doc=loader.load()
# Out:
# 100%|██████████| 31/31 [00:00<00:00, 3087.64it/s]

# %%
spliter=RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

# %%
embed=HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
# Out:
# <ipython-input-12-35c37904fc55>:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embed=HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
split_doc=spliter.split_documents(doc)

# %%
db=Chroma.from_documents(
    documents=split_doc,
    embedding=embed,
    persist_directory='db'
)

# %%
db.persist()
# Out:
# <ipython-input-15-7e0493a01d1c>:1: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   db.persist()

# %%
db.similarity_search(
    query='what is regression',
    k=2
)[1].page_content
# Out:
# 'chat to read it and show it, I will also write the Python code for it, you can read it, okay, I copied the image and I will type in it, yes, okay, this line has come, this line of our data, this line that has come, what do we call this line, what do we call regression line, regression line on this line now because I have the relation line, I have the equation, right brother, so in the future any I can give the value of x, I can find it out, then I can practice giving the input value of x, no I'

# %%
import shutil

# Path where ChromaDB is saved
chroma_db_path = "./db"

# Name of the zip file to create (without extension)
zip_filename = "chroma_backup"

# Create a zip file of the database directory
shutil.make_archive(zip_filename, 'zip', chroma_db_path)

print(f"Chroma database has been compressed to {zip_filename}.zip successfully!")
# Out:
# Chroma database has been compressed to chroma_backup.zip successfully!

# %%
import zipfile
zip_ref = zipfile.ZipFile('chroma_backup.zip', 'r')
zip_ref.extractall('bakup')
zip_ref.close()

# %%
new_db=Chroma(
    persist_directory='bakup',
    embedding_function=embed
)

# %%
new_db.similarity_search(
    query='what is regression',
    k=2
)[1].page_content
# Out:
# 'chat to read it and show it, I will also write the Python code for it, you can read it, okay, I copied the image and I will type in it, yes, okay, this line has come, this line of our data, this line that has come, what do we call this line, what do we call regression line, regression line on this line now because I have the relation line, I have the equation, right brother, so in the future any I can give the value of x, I can find it out, then I can practice giving the input value of x, no I'

# %%
my_db.similarity_search(
    query='what is regression',
    k=2
)[1].page_content
# Out:
# 'chat to read it and show it, I will also write the Python code for it, you can read it, okay, I copied the image and I will type in it, yes, okay, this line has come, this line of our data, this line that has come, what do we call this line, what do we call regression line, regression line on this line now because I have the relation line, I have the equation, right brother, so in the future any I can give the value of x, I can find it out, then I can practice giving the input value of x, no I'

# %%
llm=ChatGroq(api_key=userdata.get('chat_groq_api'))

# %%
llm2=HuggingFaceHub(repo_id="deepseek-ai/DeepSeek-R1")
# Out:
# <ipython-input-17-58dd966a248e>:1: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   llm2=HuggingFaceHub(repo_id="deepseek-ai/DeepSeek-R1")
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-17-58dd966a248e> in <cell line: 0>()
# ----> 1 llm2=HuggingFaceHub(repo_id="deepseek-ai/DeepSeek-R1")
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warn_if_direct_instance(self, *args, **kwargs)
#     212                         warned = True
#     213                         emit_warning()
# ...

# %%
retriever=db.as_retriever(
    search_type='similarity',
    search_kwargs={'k':4}
)

# %%
from langchain.chains import RetrievalQA
from langchain_core.runnables import RunnablePassthrough
from langchain.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA,ConversationalRetrievalChain

from langchain_core.prompts import PromptTemplate
from langchain_community.chat_models import ChatOpenAI
from langchain.chains.llm import LLMChain
#import stuff chain
from langchain.memory import ConversationBufferMemory
from langchain.chains.combine_documents.stuff import StuffDocumentsChain

# %%
memory=ConversationBufferMemory(
    memory_key='chat_history',
    return_messages=True
)
# Out:
# <ipython-input-36-76297b102eb7>:1: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory=ConversationBufferMemory(

# %%
con=ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=retriever,
    memory=memory,
    combine_docs_chain_kwargs={'prompt':PromptTemplate.from_template(
        """You are an AI assistant that provides accurate and concise answers.
Use the following retrieved documents to answer the question. If you don't know, say "I don't know."

Context:
{context}

Question:
{question}

Answer:
""")})

# %%
con.get_prompts()
# Out:
# []

# %%
con.run({'question':'what is newyork'})
# Out:
# "I don't have specific information about New York in the provided documents. New York can refer to either a state or a city in the United States of America. The state of New York is located in the Northeastern United States and is bordered by New Jersey, Pennsylvania, Connecticut, Massachusetts, and Vermont. The city of New York is the most populous city in the United States and is located in the state of New York. It is composed of five boroughs: The Bronx, Brooklyn, Manhattan, Queens, and Staten Island."

# %%
db2=Chroma.from_documents(
    documents=split_doc,
    embedding=HuggingFaceEmbeddings(),
    persist_directory='/content/db'
)
# Out:
# <ipython-input-53-4961ff8970f2>:3: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embedding=HuggingFaceEmbeddings(),
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-4961ff8970f2> in <cell line: 0>()
# ----> 1 db2=Chroma.from_documents(
#       2     documents=split_doc,
#       3     embedding=HuggingFaceEmbeddings(),
#       4     persist_directory='/content/db'
#       5 )
#
# /usr/local/lib/python3.11/dist-packages/langchain_community/vectorstores/chroma.py in from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885         texts = [doc.page_content for doc in documents]
# ...

# %%
db.persist()

# %%
#zip db
# !zip /content/database1.zip /content/db
# Out:
#   adding: content/db/ (stored 0%)

# %%
#open database
db2=Chroma(
    persist_directory='/content/db',
    embedding_function=HuggingFaceEmbeddings()
)
# Out:
# <ipython-input-56-a72ebe1e8b07>:4: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embedding_function=HuggingFaceEmbeddings()
# <ipython-input-56-a72ebe1e8b07>:2: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   db2=Chroma(

# %%
db2.similarity_search(
    query='what is regression',
    k=2
)[1].page_content
# Out:
# "we have to predict the number, the value is the problem and this is a regression problem, okay it is like this so for regression we will apply regression, which is the multiple regression, which regression algorithm if I see the list of regression algorithms then it is linear support vector regression, method, numerical regression, elastic regression, logistic regression, which one we don't know which one to apply, all are performing regression but when we get a task, we first apply an"

# %%
import gradio as gr
def chat(query,histroy):
  result=con.run({'question':query,'chat_history':histroy})
  return result

# %%
app=gr.ChatInterface(chat,theme=gr.themes.Soft(),title='Chat With Nasir Hussain')
# Out:
# /usr/local/lib/python3.11/dist-packages/gradio/components/chatbot.py:288: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   warnings.warn(

# %%
app.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://5f6c345e65a4d625ab.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5f6c345e65a4d625ab.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
embeddings =HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
db=Chroma.from_documents(
    documents=split_doc,
    embedding=embeddings,
    persist_directory='db2'
)

# %%
db.persist()

# %%
db.similarity_search(
    query='what is mean median',
    k=2
)[1].page_content
# Out:
# 'ok, look brother, main median mode, so what do we have in simple terms, what is the central tendency of our data, okay, mean median mode tells the center of our data, what does median also do, it tells the center of our data, so then what is the difference between mean and median, if there is an outlier in our data, then what can we do through median, we can find the correct mean, the correct center, otherwise what happens due to outlier, the mind gets disturbed, what is mode, the most repeated'

# %%
# !zip /content/database4.zip /content/db2
# Out:
#   adding: content/db2/ (stored 0%)

# %%
import os
os.environ['COHERE_API_KEY']='coAo9TlUCIFfxK2rELUF9UESnlm70Y51A9SDjrMH'

# %%
# !pip install cohere
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.5/252.5 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 77.3 MB/s eta 0:00:00
# ...

# %%
vector_db = Chroma(persist_directory='/content/db2', embedding_function=embeddings)
